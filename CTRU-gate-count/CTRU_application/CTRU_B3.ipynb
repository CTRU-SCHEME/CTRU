# %%
load("../framework/instance_gen.sage")

verbosity = 2

# CTRU-512 parameters
print("============= CTRU-512")
n = 512
m = 512
q = 3457
D_s = build_centered_binomial_law(3)
D_e = D_s

_, _, inst = initialize_from_LWE_instance(DBDD_predict_diag, n, q,
                                          m, D_e, D_s, verbosity=verbosity)

inst.integrate_q_vectors(q, report_every=20)
print(" Attack Estimation via GSA + Interesect model ")
inst.estimate_attack()
print(" Attack Estimation via simulation + probabilistic model ")
inst.estimate_attack(probabilistic=True, lift_union_bound=True, silent=False)

print("============= CTRU-768")

# CTRU-768 parameters
n = 768
m = 768
q = 3457
D_s = build_centered_binomial_law(3)
D_e = D_s

_, _, inst = initialize_from_LWE_instance(DBDD_predict_diag, n, q,
                                          m, D_e, D_s, verbosity=verbosity)

inst.integrate_q_vectors(q, report_every=20)
print(" Attack Estimation via GSA + Interesect model ")
inst.estimate_attack()
print(" Attack Estimation via simulation + probabilistic model ")

inst.estimate_attack(probabilistic=True, lift_union_bound=True, silent=False)

print("============= CTRU-1024")

# CTRU-1024 parameters
n = 1024
m = 1024
q = 3457
D_s = build_centered_binomial_law(3)
D_e = D_s

_, _, inst = initialize_from_LWE_instance(DBDD_predict_diag, n, q,
                                          m, D_e, D_s, verbosity=verbosity)

inst.integrate_q_vectors(q, report_every=20)
print(" Attack Estimation via GSA + Interesect model ")
inst.estimate_attack()
print(" Attack Estimation via simulation + probabilistic model ")
inst.estimate_attack(probabilistic=True, lift_union_bound=True, silent=False)
# Out:
# ============= CTRU-512
#       Build DBDD from LWE
#  n=512 	 m=512 	 q=3457
#        Integrating q-vectors
#  [...20]   integrate short vector hint   3457*c1023 ∈ Λ   	 Unworthy hint, Rejected.
#  Attack Estimation via GSA + Interesect model
#        Attack Estimation
#  ln(dvol)=3964.2579619 	 ln(Bvol)=4171.8560972 	 ln(Svol)=415.1962707 	δ(β)=1.003960
#  dim=1025 	 δ=1.003961 	 β=403.21
#
#  Attack Estimation via simulation + probabilistic model
# β= 397,	 pr=6.7543e-05, 	 cum-pr=1.1380e-04 	 rem-pr=9.9989e-0100
# β= 398,	 pr=1.5598e-04, 	 cum-pr=2.6977e-04 	 rem-pr=9.9973e-01
# β= 399,	 pr=3.4642e-04, 	 cum-pr=6.1610e-04 	 rem-pr=9.9938e-01
# β= 400,	 pr=7.3964e-04, 	 cum-pr=1.3553e-03 	 rem-pr=9.9864e-01
# β= 401,	 pr=1.5178e-03, 	 cum-pr=2.8710e-03 	 rem-pr=9.9713e-01
# β= 402,	 pr=2.9926e-03, 	 cum-pr=5.8549e-03 	 rem-pr=9.9415e-01
# β= 403,	 pr=5.6683e-03, 	 cum-pr=1.1490e-02 	 rem-pr=9.8851e-01
# β= 404,	 pr=1.0313e-02, 	 cum-pr=2.1684e-02 	 rem-pr=9.7832e-01
# β= 405,	 pr=1.8021e-02, 	 cum-pr=3.9314e-02 	 rem-pr=9.6069e-01
# β= 406,	 pr=3.0244e-02, 	 cum-pr=6.8370e-02 	 rem-pr=9.3163e-01
# β= 407,	 pr=4.8756e-02, 	 cum-pr=1.1379e-01 	 rem-pr=8.8621e-01
# β= 408,	 pr=7.5513e-02, 	 cum-pr=1.8071e-01 	 rem-pr=8.1929e-01
# β= 409,	 pr=1.1240e-01, 	 cum-pr=2.7280e-01 	 rem-pr=7.2720e-01
# β= 410,	 pr=1.6088e-01, 	 cum-pr=3.8979e-01 	 rem-pr=6.1021e-01
# β= 411,	 pr=2.2157e-01, 	 cum-pr=5.2500e-01 	 rem-pr=4.7500e-01
# β= 412,	 pr=2.9391e-01, 	 cum-pr=6.6460e-01 	 rem-pr=3.3540e-01
# β= 413,	 pr=3.7594e-01, 	 cum-pr=7.9069e-01 	 rem-pr=2.0931e-01
# β= 414,	 pr=4.6440e-01, 	 cum-pr=8.8790e-01 	 rem-pr=1.1210e-01
# β= 415,	 pr=5.5504e-01, 	 cum-pr=9.5012e-01 	 rem-pr=4.9882e-02
# β= 416,	 pr=6.4324e-01, 	 cum-pr=9.8220e-01 	 rem-pr=1.7796e-02
# β= 417,	 pr=7.2468e-01, 	 cum-pr=9.9510e-01 	 rem-pr=4.8996e-03
# β= 418,	 pr=7.9601e-01, 	 cum-pr=9.9900e-01 	 rem-pr=9.9948e-04
#        Attack Estimation
#  ln(dvol)=3964.2579619 	 ln(Bvol)=4171.8560972 	 ln(Svol)=415.1962707 	δ(β)=1.003907
#  dim=1025 	 	 	 β=411.10
#
# ============= CTRU-768
#       Build DBDD from LWE
#  n=768 	 m=768 	 q=3457
#        Integrating q-vectors
#  [...20]   integrate short vector hint   3457*c1535 ∈ Λ   	 Worthy hint !   dim=1536, δ=1.00279462, β=657.00
#  [...20]   integrate short vector hint   3457*c1515 ∈ Λ   	 Worthy hint !   dim=1516, δ=1.00279594, β=656.63
#  Attack Estimation via GSA + Interesect model
#        Attack Estimation
#  ln(dvol)=5636.5154113 	 ln(Bvol)=5940.0060447 	 ln(Svol)=606.9812668 	δ(β)=1.002796
#  dim=1498 	 δ=1.002796 	 β=656.52
#
#  Attack Estimation via simulation + probabilistic model
# β= 656,	 pr=1.1165e-04, 	 cum-pr=2.1025e-04 	 rem-pr=9.9979e-0100
# β= 657,	 pr=2.2561e-04, 	 cum-pr=4.3581e-04 	 rem-pr=9.9956e-01
# β= 658,	 pr=4.4253e-04, 	 cum-pr=8.7815e-04 	 rem-pr=9.9912e-01
# β= 659,	 pr=8.4254e-04, 	 cum-pr=1.7200e-03 	 rem-pr=9.9828e-01
# β= 660,	 pr=1.5569e-03, 	 cum-pr=3.2741e-03 	 rem-pr=9.9673e-01
# β= 661,	 pr=2.7918e-03, 	 cum-pr=6.0568e-03 	 rem-pr=9.9394e-01
# β= 662,	 pr=4.8583e-03, 	 cum-pr=1.0886e-02 	 rem-pr=9.8911e-01
# β= 663,	 pr=8.2041e-03, 	 cum-pr=1.9000e-02 	 rem-pr=9.8100e-01
# β= 664,	 pr=1.3444e-02, 	 cum-pr=3.2189e-02 	 rem-pr=9.6781e-01
# β= 665,	 pr=2.1381e-02, 	 cum-pr=5.2882e-02 	 rem-pr=9.4712e-01
# β= 666,	 pr=3.3001e-02, 	 cum-pr=8.4138e-02 	 rem-pr=9.1586e-01
# β= 667,	 pr=4.9445e-02, 	 cum-pr=1.2942e-01 	 rem-pr=8.7058e-01
# β= 668,	 pr=7.1929e-02, 	 cum-pr=1.9204e-01 	 rem-pr=8.0796e-01
# β= 669,	 pr=1.0162e-01, 	 cum-pr=2.7415e-01 	 rem-pr=7.2585e-01
# β= 670,	 pr=1.3949e-01, 	 cum-pr=3.7540e-01 	 rem-pr=6.2460e-01
# β= 671,	 pr=1.8610e-01, 	 cum-pr=4.9164e-01 	 rem-pr=5.0836e-01
# β= 672,	 pr=2.4148e-01, 	 cum-pr=6.1439e-01 	 rem-pr=3.8561e-01
# β= 673,	 pr=3.0495e-01, 	 cum-pr=7.3198e-01 	 rem-pr=2.6802e-01
# β= 674,	 pr=3.7511e-01, 	 cum-pr=8.3252e-01 	 rem-pr=1.6748e-01
# β= 675,	 pr=4.4988e-01, 	 cum-pr=9.0787e-01 	 rem-pr=9.2134e-02
# β= 676,	 pr=5.2670e-01, 	 cum-pr=9.5639e-01 	 rem-pr=4.3607e-02
# β= 677,	 pr=6.0274e-01, 	 cum-pr=9.8268e-01 	 rem-pr=1.7323e-02
# β= 678,	 pr=6.7525e-01, 	 cum-pr=9.9437e-01 	 rem-pr=5.6258e-03
# β= 679,	 pr=7.4183e-01, 	 cum-pr=9.9855e-01 	 rem-pr=1.4524e-03
# β= 680,	 pr=8.0068e-01, 	 cum-pr=9.9971e-01 	 rem-pr=2.8949e-04
#        Attack Estimation
#  ln(dvol)=5636.5154113 	 ln(Bvol)=5940.0060447 	 ln(Svol)=606.9812668 	δ(β)=1.002751
#  dim=1498 	 	 	 β=671.31
#
# ============= CTRU-1024
#       Build DBDD from LWE
#  n=1024 	 m=1024 	 q=3457
#        Integrating q-vectors
#  [...20]   integrate short vector hint   3457*c2047 ∈ Λ   	 Worthy hint !   dim=2048, δ=1.00217649, β=919.76
#  [...20]   integrate short vector hint   3457*c2027 ∈ Λ   	 Worthy hint !   dim=2028, δ=1.00217784, β=918.98
#  [...20]   integrate short vector hint   3457*c2007 ∈ Λ   	 Worthy hint !   dim=2008, δ=1.00217909, β=918.37
#  [...20]   integrate short vector hint   3457*c1987 ∈ Λ   	 Worthy hint !   dim=1988, δ=1.00217967, β=917.96
#  [...20]   integrate short vector hint   3457*c1967 ∈ Λ   	 Worthy hint !   dim=1968, δ=1.00218010, β=917.75
#  Attack Estimation via GSA + Interesect model
#        Attack Estimation
#  ln(dvol)=7205.4823502 	 ln(Bvol)=7602.2299584 	 ln(Svol)=793.4952166 	δ(β)=1.002180
#  dim=1958 	 δ=1.002180 	 β=917.72
#
#  Attack Estimation via simulation + probabilistic model
# β= 922,	 pr=5.9835e-05, 	 cum-pr=1.1908e-04 	 rem-pr=9.9988e-0100
# β= 923,	 pr=1.1487e-04, 	 cum-pr=2.3394e-04 	 rem-pr=9.9977e-01
# β= 924,	 pr=2.1533e-04, 	 cum-pr=4.4922e-04 	 rem-pr=9.9955e-01
# β= 925,	 pr=3.9411e-04, 	 cum-pr=8.4315e-04 	 rem-pr=9.9916e-01
# β= 926,	 pr=7.0420e-04, 	 cum-pr=1.5468e-03 	 rem-pr=9.9845e-01
# β= 927,	 pr=1.2284e-03, 	 cum-pr=2.7733e-03 	 rem-pr=9.9723e-01
# β= 928,	 pr=2.0920e-03, 	 cum-pr=4.8595e-03 	 rem-pr=9.9514e-01
# β= 929,	 pr=3.4779e-03, 	 cum-pr=8.3205e-03 	 rem-pr=9.9168e-01
# β= 930,	 pr=5.6446e-03, 	 cum-pr=1.3918e-02 	 rem-pr=9.8608e-01
# β= 931,	 pr=8.9437e-03, 	 cum-pr=2.2737e-02 	 rem-pr=9.7726e-01
# β= 932,	 pr=1.3835e-02, 	 cum-pr=3.6258e-02 	 rem-pr=9.6374e-01
# β= 933,	 pr=2.0897e-02, 	 cum-pr=5.6397e-02 	 rem-pr=9.4360e-01
# β= 934,	 pr=3.0820e-02, 	 cum-pr=8.5479e-02 	 rem-pr=9.1452e-01
# β= 935,	 pr=4.4393e-02, 	 cum-pr=1.2608e-01 	 rem-pr=8.7392e-01
# β= 936,	 pr=6.2459e-02, 	 cum-pr=1.8066e-01 	 rem-pr=8.1934e-01
# β= 937,	 pr=8.5855e-02, 	 cum-pr=2.5101e-01 	 rem-pr=7.4899e-01
# β= 938,	 pr=1.1533e-01, 	 cum-pr=3.3739e-01 	 rem-pr=6.6261e-01
# β= 939,	 pr=1.5144e-01, 	 cum-pr=4.3774e-01 	 rem-pr=5.6226e-01
# β= 940,	 pr=1.9448e-01, 	 cum-pr=5.4708e-01 	 rem-pr=4.5292e-01
# β= 941,	 pr=2.4434e-01, 	 cum-pr=6.5775e-01 	 rem-pr=3.4225e-01
# β= 942,	 pr=3.0049e-01, 	 cum-pr=7.6059e-01 	 rem-pr=2.3941e-01
# β= 943,	 pr=3.6196e-01, 	 cum-pr=8.4725e-01 	 rem-pr=1.5275e-01
# β= 944,	 pr=4.2736e-01, 	 cum-pr=9.1253e-01 	 rem-pr=8.7472e-02
# β= 945,	 pr=4.9496e-01, 	 cum-pr=9.5582e-01 	 rem-pr=4.4177e-02
# β= 946,	 pr=5.6284e-01, 	 cum-pr=9.8069e-01 	 rem-pr=1.9312e-02
# β= 947,	 pr=6.2904e-01, 	 cum-pr=9.9284e-01 	 rem-pr=7.1641e-03
# β= 948,	 pr=6.9175e-01, 	 cum-pr=9.9779e-01 	 rem-pr=2.2084e-03
# β= 949,	 pr=7.4941e-01, 	 cum-pr=9.9945e-01 	 rem-pr=5.5339e-04
#        Attack Estimation
#  ln(dvol)=7205.4823502 	 ln(Bvol)=7602.2299584 	 ln(Svol)=793.4952166 	δ(β)=1.002141
#  dim=1958 	 	 	 β=939.78
# (939.780744744142, None)
