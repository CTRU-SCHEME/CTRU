# %%
load("../framework/instance_gen.sage")

verbosity = 2

# CTRU-512 parameters
print("============= CTRU-512")
n = 512
m = 512
q = 3457
D_s = build_centered_binomial_law(2)
D_e = D_s

_, _, inst = initialize_from_LWE_instance(DBDD_predict_diag, n, q,
                                          m, D_e, D_s, verbosity=verbosity)

inst.integrate_q_vectors(q, report_every=20)
print(" Attack Estimation via GSA + Interesect model ")
inst.estimate_attack()
print(" Attack Estimation via simulation + probabilistic model ")
inst.estimate_attack(probabilistic=True, lift_union_bound=True, silent=False)

print("============= CTRU-768")

# CTRU-768 parameters
n = 768
m = 768
q = 3457
D_s = build_centered_binomial_law(2)
D_e = D_s

_, _, inst = initialize_from_LWE_instance(DBDD_predict_diag, n, q,
                                          m, D_e, D_s, verbosity=verbosity)

inst.integrate_q_vectors(q, report_every=20)
print(" Attack Estimation via GSA + Interesect model ")
inst.estimate_attack()
print(" Attack Estimation via simulation + probabilistic model ")

inst.estimate_attack(probabilistic=True, lift_union_bound=True, silent=False)

print("============= CTRU-1024")

# CTRU-1024 parameters
n = 1024
m = 1024
q = 3457
D_s = build_centered_binomial_law(2)
D_e = D_s

_, _, inst = initialize_from_LWE_instance(DBDD_predict_diag, n, q,
                                          m, D_e, D_s, verbosity=verbosity)

inst.integrate_q_vectors(q, report_every=20)
print(" Attack Estimation via GSA + Interesect model ")
inst.estimate_attack()
print(" Attack Estimation via simulation + probabilistic model ")
inst.estimate_attack(probabilistic=True, lift_union_bound=True, silent=False)
# Out:
# ============= CTRU-512
#       Build DBDD from LWE
#  n=512 	 m=512 	 q=3457
#        Integrating q-vectors
#  [...20]   integrate short vector hint   3457*c1023 ∈ Λ   	 Worthy hint !   dim=1024, δ=1.00413067, β=379.45
#  Attack Estimation via GSA + Interesect model
#        Attack Estimation
#  ln(dvol)=4025.1892813 	 ln(Bvol)=4025.1892813 	 ln(Svol)=0.0000000 	δ(β)=1.004131
#  dim=1007 	 δ=1.004132 	 β=379.31
#
#  Attack Estimation via simulation + probabilistic model
# β= 373,	 pr=6.2633e-05, 	 cum-pr=1.0268e-04 	 rem-pr=9.9990e-0100
# β= 374,	 pr=1.5025e-04, 	 cum-pr=2.5291e-04 	 rem-pr=9.9975e-01
# β= 375,	 pr=3.4548e-04, 	 cum-pr=5.9831e-04 	 rem-pr=9.9940e-01
# β= 376,	 pr=7.6122e-04, 	 cum-pr=1.3591e-03 	 rem-pr=9.9864e-01
# β= 377,	 pr=1.6066e-03, 	 cum-pr=2.9635e-03 	 rem-pr=9.9704e-01
# β= 378,	 pr=3.2470e-03, 	 cum-pr=6.2008e-03 	 rem-pr=9.9380e-01
# β= 379,	 pr=6.2825e-03, 	 cum-pr=1.2444e-02 	 rem-pr=9.8756e-01
# β= 380,	 pr=1.1636e-02, 	 cum-pr=2.3935e-02 	 rem-pr=9.7606e-01
# β= 381,	 pr=2.0626e-02, 	 cum-pr=4.4067e-02 	 rem-pr=9.5593e-01
# β= 382,	 pr=3.4994e-02, 	 cum-pr=7.7520e-02 	 rem-pr=9.2248e-01
# β= 383,	 pr=5.6833e-02, 	 cum-pr=1.2995e-01 	 rem-pr=8.7005e-01
# β= 384,	 pr=8.8378e-02, 	 cum-pr=2.0684e-01 	 rem-pr=7.9316e-01
# β= 385,	 pr=1.3165e-01, 	 cum-pr=3.1126e-01 	 rem-pr=6.8874e-01
# β= 386,	 pr=1.8797e-01, 	 cum-pr=4.4072e-01 	 rem-pr=5.5928e-01
# β= 387,	 pr=2.5749e-01, 	 cum-pr=5.8473e-01 	 rem-pr=4.1527e-01
# β= 388,	 pr=3.3879e-01, 	 cum-pr=7.2542e-01 	 rem-pr=2.7458e-01
# β= 389,	 pr=4.2884e-01, 	 cum-pr=8.4317e-01 	 rem-pr=1.5683e-01
# β= 390,	 pr=5.2319e-01, 	 cum-pr=9.2522e-01 	 rem-pr=7.4778e-02
# β= 391,	 pr=6.1667e-01, 	 cum-pr=9.7134e-01 	 rem-pr=2.8665e-02
# β= 392,	 pr=7.0416e-01, 	 cum-pr=9.9152e-01 	 rem-pr=8.4801e-03
# β= 393,	 pr=7.8146e-01, 	 cum-pr=9.9815e-01 	 rem-pr=1.8532e-03
# β= 394,	 pr=8.4589e-01, 	 cum-pr=9.9971e-01 	 rem-pr=2.8560e-04
#        Attack Estimation
#  ln(dvol)=4025.1892813 	 ln(Bvol)=4025.1892813 	 ln(Svol)=0.0000000 	δ(β)=1.004076
#  dim=1007 	 	 	 β=386.70
#
# ============= CTRU-768
#       Build DBDD from LWE
#  n=768 	 m=768 	 q=3457
#        Integrating q-vectors
#  [...20]   integrate short vector hint   3457*c1535 ∈ Λ   	 Worthy hint !   dim=1536, δ=1.00290947, β=621.78
#  [...20]   integrate short vector hint   3457*c1515 ∈ Λ   	 Worthy hint !   dim=1516, δ=1.00291230, β=621.06
#  [...20]   integrate short vector hint   3457*c1495 ∈ Λ   	 Worthy hint !   dim=1496, δ=1.00291373, β=620.57
#  [...20]   integrate short vector hint   3457*c1475 ∈ Λ   	 Worthy hint !   dim=1476, δ=1.00291470, β=620.32
#  Attack Estimation via GSA + Interesect model
#        Attack Estimation
#  ln(dvol)=5687.4131951 	 ln(Bvol)=5687.4131951 	 ln(Svol)=0.0000000 	δ(β)=1.002914
#  dim=1467 	 δ=1.002915 	 β=620.30
#
#  Attack Estimation via simulation + probabilistic model
# β= 619,	 pr=8.1864e-05, 	 cum-pr=1.4883e-04 	 rem-pr=9.9985e-0100
# β= 620,	 pr=1.7206e-04, 	 cum-pr=3.2087e-04 	 rem-pr=9.9968e-01
# β= 621,	 pr=3.5028e-04, 	 cum-pr=6.7103e-04 	 rem-pr=9.9933e-01
# β= 622,	 pr=6.9062e-04, 	 cum-pr=1.3612e-03 	 rem-pr=9.9864e-01
# β= 623,	 pr=1.3186e-03, 	 cum-pr=2.6780e-03 	 rem-pr=9.9732e-01
# β= 624,	 pr=2.4377e-03, 	 cum-pr=5.1091e-03 	 rem-pr=9.9489e-01
# β= 625,	 pr=4.3632e-03, 	 cum-pr=9.4500e-03 	 rem-pr=9.9055e-01
# β= 626,	 pr=7.5611e-03, 	 cum-pr=1.6940e-02 	 rem-pr=9.8306e-01
# β= 627,	 pr=1.2686e-02, 	 cum-pr=2.9411e-02 	 rem-pr=9.7059e-01
# β= 628,	 pr=2.0607e-02, 	 cum-pr=4.9411e-02 	 rem-pr=9.5059e-01
# β= 629,	 pr=3.2413e-02, 	 cum-pr=8.0222e-02 	 rem-pr=9.1978e-01
# β= 630,	 pr=4.9374e-02, 	 cum-pr=1.2564e-01 	 rem-pr=8.7436e-01
# β= 631,	 pr=7.2853e-02, 	 cum-pr=1.8934e-01 	 rem-pr=8.1066e-01
# β= 632,	 pr=1.0416e-01, 	 cum-pr=2.7378e-01 	 rem-pr=7.2622e-01
# β= 633,	 pr=1.4437e-01, 	 cum-pr=3.7862e-01 	 rem-pr=6.2138e-01
# β= 634,	 pr=1.9406e-01, 	 cum-pr=4.9920e-01 	 rem-pr=5.0080e-01
# β= 635,	 pr=2.5316e-01, 	 cum-pr=6.2599e-01 	 rem-pr=3.7401e-01
# β= 636,	 pr=3.2078e-01, 	 cum-pr=7.4596e-01 	 rem-pr=2.5404e-01
# β= 637,	 pr=3.9518e-01, 	 cum-pr=8.4635e-01 	 rem-pr=1.5365e-01
# β= 638,	 pr=4.7385e-01, 	 cum-pr=9.1916e-01 	 rem-pr=8.0841e-02
# β= 639,	 pr=5.5380e-01, 	 cum-pr=9.6393e-01 	 rem-pr=3.6071e-02
# β= 640,	 pr=6.3184e-01, 	 cum-pr=9.8672e-01 	 rem-pr=1.3280e-02
# β= 641,	 pr=7.0498e-01, 	 cum-pr=9.9608e-01 	 rem-pr=3.9179e-03
# β= 642,	 pr=7.7079e-01, 	 cum-pr=9.9910e-01 	 rem-pr=8.9804e-04
#        Attack Estimation
#  ln(dvol)=5687.4131951 	 ln(Bvol)=5687.4131951 	 ln(Svol)=0.0000000 	δ(β)=1.002868
#  dim=1467 	 	 	 β=634.25
#
# ============= CTRU-1024
#       Build DBDD from LWE
#  n=1024 	 m=1024 	 q=3457
#        Integrating q-vectors
#  [...20]   integrate short vector hint   3457*c2047 ∈ Λ   	 Worthy hint !   dim=2048, δ=1.00226334, β=873.21
#  [...20]   integrate short vector hint   3457*c2027 ∈ Λ   	 Worthy hint !   dim=2028, δ=1.00226553, β=872.10
#  [...20]   integrate short vector hint   3457*c2007 ∈ Λ   	 Worthy hint !   dim=2008, δ=1.00226737, β=871.15
#  [...20]   integrate short vector hint   3457*c1987 ∈ Λ   	 Worthy hint !   dim=1988, δ=1.00226882, β=870.37
#  [...20]   integrate short vector hint   3457*c1967 ∈ Λ   	 Worthy hint !   dim=1968, δ=1.00226988, β=869.78
#  [...20]   integrate short vector hint   3457*c1947 ∈ Λ   	 Worthy hint !   dim=1948, δ=1.00227079, β=869.37
#  [...20]   integrate short vector hint   3457*c1927 ∈ Λ   	 Worthy hint !   dim=1928, δ=1.00227125, β=869.17
#  Attack Estimation via GSA + Interesect model
#        Attack Estimation
#  ln(dvol)=7284.4518573 	 ln(Bvol)=7284.4518573 	 ln(Svol)=0.0000000 	δ(β)=1.002271
#  dim=1919 	 δ=1.002271 	 β=869.14
#
#  Attack Estimation via simulation + probabilistic model
# β= 873,	 pr=6.4381e-05, 	 cum-pr=1.2512e-04 	 rem-pr=9.9987e-0100
# β= 874,	 pr=1.2637e-04, 	 cum-pr=2.5148e-04 	 rem-pr=9.9975e-01
# β= 875,	 pr=2.4174e-04, 	 cum-pr=4.9316e-04 	 rem-pr=9.9951e-01
# β= 876,	 pr=4.5068e-04, 	 cum-pr=9.4362e-04 	 rem-pr=9.9906e-01
# β= 877,	 pr=8.1876e-04, 	 cum-pr=1.7616e-03 	 rem-pr=9.9824e-01
# β= 878,	 pr=1.4494e-03, 	 cum-pr=3.2085e-03 	 rem-pr=9.9679e-01
# β= 879,	 pr=2.5002e-03, 	 cum-pr=5.7006e-03 	 rem-pr=9.9430e-01
# β= 880,	 pr=4.2023e-03, 	 cum-pr=9.8790e-03 	 rem-pr=9.9012e-01
# β= 881,	 pr=6.8825e-03, 	 cum-pr=1.6693e-02 	 rem-pr=9.8331e-01
# β= 882,	 pr=1.0984e-02, 	 cum-pr=2.7494e-02 	 rem-pr=9.7251e-01
# β= 883,	 pr=1.7082e-02, 	 cum-pr=4.4106e-02 	 rem-pr=9.5589e-01
# β= 884,	 pr=2.5890e-02, 	 cum-pr=6.8855e-02 	 rem-pr=9.3115e-01
# β= 885,	 pr=3.8249e-02, 	 cum-pr=1.0447e-01 	 rem-pr=8.9553e-01
# β= 886,	 pr=5.5085e-02, 	 cum-pr=1.5380e-01 	 rem-pr=8.4620e-01
# β= 887,	 pr=7.7356e-02, 	 cum-pr=2.1926e-01 	 rem-pr=7.8074e-01
# β= 888,	 pr=1.0595e-01, 	 cum-pr=3.0198e-01 	 rem-pr=6.9802e-01
# β= 889,	 pr=1.4158e-01, 	 cum-pr=4.0081e-01 	 rem-pr=5.9919e-01
# β= 890,	 pr=1.8466e-01, 	 cum-pr=5.1146e-01 	 rem-pr=4.8854e-01
# β= 891,	 pr=2.3520e-01, 	 cum-pr=6.2636e-01 	 rem-pr=3.7364e-01
# β= 892,	 pr=2.9269e-01, 	 cum-pr=7.3572e-01 	 rem-pr=2.6428e-01
# β= 893,	 pr=3.5611e-01, 	 cum-pr=8.2983e-01 	 rem-pr=1.7017e-01
# β= 894,	 pr=4.2394e-01, 	 cum-pr=9.0197e-01 	 rem-pr=9.8027e-02
# β= 895,	 pr=4.9427e-01, 	 cum-pr=9.5042e-01 	 rem-pr=4.9575e-02
# β= 896,	 pr=5.6493e-01, 	 cum-pr=9.7843e-01 	 rem-pr=2.1569e-02
# β= 897,	 pr=6.3372e-01, 	 cum-pr=9.9210e-01 	 rem-pr=7.9003e-03
# β= 898,	 pr=6.9859e-01, 	 cum-pr=9.9762e-01 	 rem-pr=2.3813e-03
# β= 899,	 pr=7.5784e-01, 	 cum-pr=9.9942e-01 	 rem-pr=5.7665e-04
#        Attack Estimation
#  ln(dvol)=7284.4518573 	 ln(Bvol)=7284.4518573 	 ln(Svol)=0.0000000 	δ(β)=1.002231
#  dim=1919 	 	 	 β=890.12
# (890.116150371951, None)
